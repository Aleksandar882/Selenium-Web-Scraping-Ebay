# %%
#requirements for colab
# install chromium, its driver, and selenium
# !apt update
# !apt install chromium-chromedriver
# !pip install selenium
# set options to be headless, ..
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# open it, go to a website, and get results
wd = webdriver.Chrome(options=options)
wd.get("https://www.ebay.com/sch/i.html?_from=R40&_trksid=p2380057.m570.l1313&_nkw=graphic+cards&_sacat=0")
print(wd.page_source)  # results
#divs = wd.find_element(By.TAG_NAME, 'div')

import requests
from bs4 import BeautifulSoup
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [557 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [1,306 kB]
# Get:9 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease [18.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [1,410 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,134 kB]
# ...

# %%
from selenium.webdriver.common.by import By

soup = BeautifulSoup(wd.page_source,features='html.parser')

wd.page_source


elems = wd.find_elements(By.CLASS_NAME, "s-item__wrapper")



titles=[]
ratings=[]
prices=[]

elems
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="64b57f763ce0add9448c9630494e2c90", element="A790210CF6520E2F1D1BFB240C34BEA3_element_59")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64b57f763ce0add9448c9630494e2c90", element="A790210CF6520E2F1D1BFB240C34BEA3_element_60")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64b57f763ce0add9448c9630494e2c90", element="A790210CF6520E2F1D1BFB240C34BEA3_element_39")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64b57f763ce0add9448c9630494e2c90", element="A790210CF6520E2F1D1BFB240C34BEA3_element_61")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64b57f763ce0add9448c9630494e2c90", element="A790210CF6520E2F1D1BFB240C34BEA3_element_62")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64b57f763ce0add9448c9630494e2c90", element="A790210CF6520E2F1D1BFB240C34BEA3_element_63")>,
# ...

# %%
for x in range(0, len(elems)):
  try:
    ratings.append(elems[x].find_element(By.CLASS_NAME, "x-star-rating").text)
  except:
    continue
  titles.append(elems[x].find_element(By.CLASS_NAME, "s-item__title").text)
  prices.append(elems[x].find_element(By.CLASS_NAME, "s-item__price").text)

# %%
prices=[]
titles=[]
ratings=[]

# %%
import pandas as pd



dict_={'Title':titles,'Rating':ratings, 'Price':prices}

df2=pd.DataFrame(dict_)

# %%
df2
# Out:
#                                                Title               Rating  \
# 0  ZOTAC GEFORCE GTX 1070 8GB GDDR5 GAMING GRAPHI...  5.0 out of 5 stars.
# 1  SAPPHIRE Nitro+ Radeon RX 580 8GB GDDR5 Graphi...  4.5 out of 5 stars.
# 2  MSI NVIDIA GeForce RTX 2070 8GB GDDR6 Graphics...  4.5 out of 5 stars.
# 3  ZOTAC GAMING GeForce RTX 3070 AMP Holo 8GB GDD...  5.0 out of 5 stars.
# 4  GIGABYTE NVIDIA GeForce GTX 1650 4GB GDDR6 Gra...  5.0 out of 5 stars.
# 5  GIGABYTE NVIDIA GeForce GTX 1070 8 GB GDDR5 Gr...  4.5 out of 5 stars.
# 6  MSI GeForce GTX 1650 4GB GDDR6 Graphics Card (...  5.0 out of 5 stars.
# 7  NVIDIA GeForce RTX 3080 FE Founders Edition 10...  4.0 out of 5 stars.
# 8  GIGABYTE Radeon RX 560 Gaming OC 4G 4GB GDDR5 ...  4.5 out of 5 stars.
# 9  GIGABYTE GeForce RTX 3050 EAGLE OC 8GB GDDR6 G...  5.0 out of 5 stars.
#
#      Price
# 0   $89.99
# 1   $80.00
# 2  $179.99
# 3  $284.99
# 4  $165.00
# 5   $95.00
# 6   $81.00
# 7  $419.00
# 8   $19.99
# 9  $151.00
